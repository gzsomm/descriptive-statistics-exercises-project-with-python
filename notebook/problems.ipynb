# %% [markdown]
# # Descriptive statistics problems

# %% [markdown]
# ### Exercise 1
#
# We will use NumPy to obtain information to describe statistically.
#
# - Generate an array of 100 elements following a normal distribution.
# - Generate an array of 100 elements following a chi-square distribution with 3 degrees of freedom.
# - Calculate the main metrics and statistical measures that best describe the two vectors.

# %%
# 
import numpy as np
import matplotlib.pyplot as plt


muestra = 100

a1 = np.random.normal (0, 1, muestra)

plt.hist (a1, bins= 20, alpha=0.7, color='blue')
plt.show ()

a2 = np.random.chisquare (3, muestra)
plt.hist (a2, bins = 20, alpha=0.7, color='green')


a1_mean = np.mean (a1)
a2_mean = np.mean (a2)

a1_median = np.median (a1)
a2_median = np.median (a2)

a1_std = np.std (a1)
a2_std = np.std (a2)

print (f'La media de la distribución normal es {round(a1_mean,2)} mientras que para la distribución de chi-cuadrado es {round(a2_mean,2)}')
print (f'La mediana de la distribución normal es {round(a1_median, 2)} mientras que para la distribución de chi-cuadrado es {round(a2_median, 2)}')
print (f'La desviación standar de la distribución normal es {round(a1_std, 2)} mientras que para la distribución de chi-cuadrado es {round(a2_std,2)}')
# Out:
# La media de la distribución normal es 0.02 mientras que para la distribución de chi-cuadrado es 3.38
# La mediana de la distribución normal es -0.07 mientras que para la distribución de chi-cuadrado es 2.65
# La desviación standar de la distribución normal es 0.97 mientras que para la distribución de chi-cuadrado es 2.84

# %% [markdown]
# ### Exercise 2
#
# Write a Python program to calculate the standard deviation of the following data:
#
# ```py
# data = [4, 2, 5, 8, 6]
# ```

# %%
# 

data = [4, 2, 5, 8, 6]
data = np.array (data)

data_std = np.std (data)
print (data_std)
# Out:
# 2.0
